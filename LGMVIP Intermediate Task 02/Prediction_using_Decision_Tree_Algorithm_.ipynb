# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score
from sklearn import datasets

# %%
df = datasets.load_iris()
iris=pd.DataFrame(df['data'], columns=['SepalLengthCm',"SepalWidthCm","PetalLengthCm","PetalWidthCm"])
iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
iris['Species']=df['target']

# %%
iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0              5.1           3.5            1.4           0.2        0
# 1              4.9           3.0            1.4           0.2        0
# 2              4.7           3.2            1.3           0.2        0
# 3              4.6           3.1            1.5           0.2        0
# 4              5.0           3.6            1.4           0.2        0
# ..             ...           ...            ...           ...      ...
# 145            6.7           3.0            5.2           2.3        2
# 146            6.3           2.5            5.0           1.9        2
# 147            6.5           3.0            5.2           2.0        2
# 148            6.2           3.4            5.4           2.3        2
# 149            5.9           3.0            5.1           1.8        2
#
# [150 rows x 5 columns]

# %%
iris['Species']=iris['Species'].apply(lambda x: df['target_names'][x])

# %%
iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm    Species
# 0              5.1           3.5            1.4           0.2     setosa
# 1              4.9           3.0            1.4           0.2     setosa
# 2              4.7           3.2            1.3           0.2     setosa
# 3              4.6           3.1            1.5           0.2     setosa
# 4              5.0           3.6            1.4           0.2     setosa
# ..             ...           ...            ...           ...        ...
# 145            6.7           3.0            5.2           2.3  virginica
# 146            6.3           2.5            5.0           1.9  virginica
# 147            6.5           3.0            5.2           2.0  virginica
# 148            6.2           3.4            5.4           2.3  virginica
# 149            5.9           3.0            5.1           1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# 0            5.1           3.5            1.4           0.2  setosa
# 1            4.9           3.0            1.4           0.2  setosa
# 2            4.7           3.2            1.3           0.2  setosa
# 3            4.6           3.1            1.5           0.2  setosa
# 4            5.0           3.6            1.4           0.2  setosa

# %%
iris.tail(3)

# %%
iris.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.057333       3.758000      1.199333
# std         0.828066      0.435866       1.765298      0.762238
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris['Species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris.value_counts("Species")
# Out:
# Species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
import seaborn as sns
from matplotlib import pyplot as plt
sns.countplot(x='Species', data=iris )
plt.show()

# %% [markdown]
# **SCATTER PLOT IN 2D SPACE**

# %%
# Comparing sepalLength & SepalWidth
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm',
                hue='Species', data=iris )

# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)

plt.show()

# %%
# Comparing PetalLength & PetalWidth
sns.scatterplot(x='PetalLengthCm', y='PetalWidthCm',
                hue='Species', data=iris )

# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)

plt.show()

# %% [markdown]
# **MULTIVARIATE ANALYSIS**

# %%
sns.pairplot(iris,hue="Species",size=2)
plt.show()
# Out:
# D:\Games\New folder\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
plot = sns.FacetGrid(iris, hue="Species")
plot.map(sns.histplot, "SepalLengthCm").add_legend()

# Create a FacetGrid object for SepalWidthCm
plot = sns.FacetGrid(iris, hue="Species")
plot.map(sns.histplot, "SepalWidthCm").add_legend()

# Create a FacetGrid object for PetalLengthCm
plot = sns.FacetGrid(iris, hue="Species")
plot.map(sns.histplot, "PetalLengthCm").add_legend()

# Create a FacetGrid object for PetalWidthCm
plot = sns.FacetGrid(iris, hue="Species")
plot.map(sns.histplot, "PetalWidthCm").add_legend()

plt.show()

# %% [markdown]
# **Heatmaps**

# %%
sns.heatmap(iris.corr(method='pearson'),annot = True)

plt.show()

# %% [markdown]
# **ClusterMap**

# %%
# Create a clustermap of the Pearson correlation matrix of the "iris" dataset
sns.clustermap(iris.corr(method='pearson'), annot=True, cmap='coolwarm', linewidths=0.5, figsize=(8, 6))

# Display the plot
plt.show()

# %% [markdown]
# **BOXPLOT**

# %%
plt.figure(figsize=(8,8))
plt.subplot(2,2,1)
sns.boxplot(x="Species",y="SepalLengthCm",data=iris)
plt.subplot(2,2,2)
sns.boxplot(x="Species",y="SepalWidthCm",data=iris)
plt.subplot(2,2,3)
sns.boxplot(x="Species",y="PetalLengthCm",data=iris)
plt.subplot(2,2,4)
sns.boxplot(x="Species",y="PetalWidthCm",data=iris)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalWidthCm'>

# %% [markdown]
# **HANDLING OUTLIER**

# %%
sns.boxplot(x='SepalWidthCm', data=iris)
plt.figure(figsize=(0.1,0.1))

# %%
# Inter Quartile Range
Q1 = np.percentile(iris['SepalWidthCm'], 25,
                interpolation = 'midpoint')

Q3 = np.percentile(iris['SepalWidthCm'], 75,
                interpolation = 'midpoint')
IQR = Q3 - Q1

# Upper bound
upper = np.where(iris['SepalWidthCm'] >= (Q3+1.5*IQR))

# Lower bound
lower = np.where(iris['SepalWidthCm'] <= (Q1-1.5*IQR))

# Removing the Outliers
iris.drop(upper[0], inplace = True)
iris.drop(lower[0], inplace = True)

sns.boxplot(x='SepalWidthCm', data=iris)
print("After removing the outliers the dataset size is :",iris.shape)
# Out:
# After removing the outliers the dataset size is : (146, 5)

# %% [markdown]
# **Model Building**

# %%
from sklearn.model_selection import train_test_split

train,test=train_test_split(iris,test_size=0.25)

# %%
X_train = train[['SepalLengthCm',"SepalWidthCm","PetalLengthCm","PetalWidthCm"]]
y_train = train.Species

# %%
X_test = test[['SepalLengthCm',"SepalWidthCm","PetalLengthCm","PetalWidthCm"]]
y_test = test.Species

# %% [markdown]
# **Importing Decision Tree from Sklearn to build a classification model**

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(random_state=12)
model = dt.fit(X_train, y_train)

# %%
dt.predict(X_test)
# Out:
# array(['setosa', 'versicolor', 'virginica', 'versicolor', 'virginica',
#        'setosa', 'versicolor', 'setosa', 'setosa', 'virginica',
#        'virginica', 'versicolor', 'setosa', 'virginica', 'versicolor',
#        'versicolor', 'versicolor', 'setosa', 'setosa', 'virginica',
#        'versicolor', 'setosa', 'virginica', 'setosa', 'virginica',
#        'virginica', 'versicolor', 'setosa', 'setosa', 'virginica',
#        'versicolor', 'virginica', 'versicolor', 'setosa', 'versicolor',
#        'virginica', 'setosa'], dtype=object)

# %%
# Check accuracy of model
dt.score(X_test, y_test)
# Out:
# 0.918918918918919

# %%
#prediction
y_pred = dt.predict(X_test)

# %%
#Accuracy
from sklearn import metrics
print('Accuracy Score:', metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy Score: 0.918918918918919

# %% [markdown]
# **DECISION TREE VISULAIZATION**

# %%
# !pip install pydotplus
# !apt-get install graphviz -y
# Out:
# Collecting pydotplus
#   Downloading pydotplus-2.0.2.tar.gz (278 kB)
#      -------------------------------------- 278.7/278.7 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pyparsing>=2.0.1 in d:\games\new folder\lib\site-packages (from pydotplus) (3.0.9)
# Building wheels for collected packages: pydotplus
#   Building wheel for pydotplus (setup.py): started
#   Building wheel for pydotplus (setup.py): finished with status 'done'
#   Created wheel for pydotplus: filename=pydotplus-2.0.2-py3-none-any.whl size=24554 sha256=95956f24f7406c56ffcab9b506b5e590e4d02d21a7436cc2b0cc8b627d992c95
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\89\e5\de\6966007cf223872eedfbebbe0e074534e72e9128c8fd4b55eb
# Successfully built pydotplus
# Installing collected packages: pydotplus
# Successfully installed pydotplus-2.0.2
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# Import necessary libraries for graph viz
import six
from six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus


# Visualize the graph
dot_data = StringIO()
export_graphviz(dt, out_file=dot_data, feature_names=df.feature_names,
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22904\3411289877.py in <module>
#      13                 special_characters=True)
#      14 graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
# ---> 15 Image(graph.create_png())
#
# D:\Games\New folder\lib\site-packages\pydotplus\graphviz.py in <lambda>(f, prog)
#    1795             self.__setattr__(
#    1796                 'create_' + frmt,
# -> 1797                 lambda f=frmt, prog=self.prog: self.create(format=f, prog=prog)
#    1798             )
#    1799             f = self.__dict__['create_' + frmt]
#
# D:\Games\New folder\lib\site-packages\pydotplus\graphviz.py in create(self, prog, format)
#    1957             self.progs = find_graphviz()
#    1958             if self.progs is None:
# -> 1959                 raise InvocationException(
#    1960                     'GraphViz\'s executables not found')
#    1961
#
# InvocationException: GraphViz's executables not found

# %% [markdown]
# **Provide New/test data to this classifer and it would be able to predict the right class accordingly.**

# %%
dt.predict([[4.5, 1.9, 7.2, 2.4]])
# Out:
# D:\Games\New folder\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['virginica'], dtype=object)

# %%
dt.predict([[5.1, 2.5, 0.4, 1.2]])
# Out:
# D:\Games\New folder\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['versicolor'], dtype=object)

# %%
dt.predict([[6.1, 3.5, 1.4, 0.2]])
# Out:
# D:\Games\New folder\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['setosa'], dtype=object)
